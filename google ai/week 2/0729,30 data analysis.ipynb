# %%
#데이터 불러오기
#csv comma-seperated values

# !pwd

# esc, a / b
# Out:
# /content

# %%
# esc 컨트롤 MM 마크다운 문법으로 변함

# %%
import pandas as pd
import numpy as np

# %%
seoul_popul = pd.read_csv('/content/등록인구_20240729193429.csv')

# %%
seoul_popul #index column values
# Out:
#     동별(1)  동별(2) 2024 2/4 2024 2/4.1 2024 2/4.2 2024 2/4.3 2024 2/4.4  \
# 0   동별(1)  동별(2)  세대 (세대)      계 (명)      계 (명)      계 (명)    한국인 (명)
# 1   동별(1)  동별(2)       소계         소계         남자         여자         소계
# 2      합계     소계  4486014    9619861    4634458    4985403    9366283
# 3      합계    종로구    72394     150204      71684      78520     139189
# 4      합계     중구    65273     131800      63383      68417     121475
# 5      합계    용산구   104187     219451     105752     113699     206061
# 6      합계    성동구   133233     283853     136993     146860     276597
# 7      합계    광진구   170469     350005     166736     183269     334159
# 8      합계   동대문구   173903     360066     174065     186001     341345
# 9      합계    중랑구   188664     386782     188839     197943     381126
# 10     합계    성북구   197371     436666     207814     228852     424194
# 11     합계    강북구   143075     290252     139521     150731     285054
# ...

# %%
#head(a): 상단 a개 확인 디폴트 5개
#seoul_popul.head()
seoul_popul.tail() #tail 기능의 장점 내 전체 데이터 갯수를 확인할 수 있는 장점
# Out:
#    동별(1) 동별(2) 2024 2/4 2024 2/4.1 2024 2/4.2 2024 2/4.3 2024 2/4.4  \
# 23    합계   관악구   286338     497632     248813     248819     481145
# 24    합계   서초구   170464     411959     196029     215930     407404
# 25    합계   강남구   245046     562136     268628     293508     556570
# 26    합계   송파구   287380     658768     315963     342805     652752
# 27    합계   강동구   205956     466924     227732     239192     462646
#
#    2024 2/4.5 2024 2/4.6 2024 2/4.7 2024 2/4.8 2024 2/4.9 2024 2/4.10  \
# 23     242251     238894      16487       6562       9925        1.68
# 24     193838     213566       4555       2191       2364        2.39
# 25     266101     290469       5566       2527       3039        2.27
# 26     313205     339547       6016       2758       3258        2.27
# 27     225871     236775       4278       1861       2417        2.25
#
#    2024 2/4.11
# 23       87267
# 24       67191
# 25       89719
# 26      111724
# 27       85571

# %%
# 데이터 프레임의 인덱스
seoul_popul.index
# 데이터 프레임의 값
seoul_popul.values
# 데이터 프레임의 컬럼
seoul_popul.columns
# Out:
# Index(['동별(1)', '동별(2)', '2024 2/4', '2024 2/4.1', '2024 2/4.2', '2024 2/4.3',
#        '2024 2/4.4', '2024 2/4.5', '2024 2/4.6', '2024 2/4.7', '2024 2/4.8',
#        '2024 2/4.9', '2024 2/4.10', '2024 2/4.11'],
#       dtype='object')

# %%
seoul_popul.head(1)

seoul_popul.rename(columns={'동별(1)':'동별'},inplace=True)# pandas에서는 이대로 저장이 안됨. inplace=True 필요

# %%
pop_data='/content/서울시 자치구 (연도별) CCTV 설치현황_240630.xlsx' #이런식의 작업방식이 좋음
seoul_cctv= pd.read_excel(pop_data, header=2, usecols='C, D, E') # 3번째 행부터 불러옴 위에는 표만들때 쓰이는 엑셀형식 / usecols 필요한 컬럼만 읽어옴

# %%
seoul_cctv.head()
# Out:
#     구분     총 계  2016년 이전 설치된 CCTV
# 0    계  102380               11692
# 1  종로구    2290                 230
# 2  중 구    3021                 376
# 3  용산구    3300                 106
# 4  성동구    4514                 542

# %%
seoul_cctv.columns #list의 특징
# Out:
# Index(['구분', '총 계', '2016년 이전 설치된 CCTV '], dtype='object')

# %%
seoul_cctv.rename(columns={'구분':'구별',seoul_cctv.columns[2]:'16년이전설치'},inplace=True)

# %%
seoul_cctv.head()
# Out:
#     구별     총 계  16년이전설치
# 0    계  102380    11692
# 1  종로구    2290      230
# 2  중 구    3021      376
# 3  용산구    3300      106
# 4  성동구    4514      542

# %%
seoul_cctv.sort_values(by='총 계', ascending=False).head(6) #ascending=False 내림차순 정렬
# Out:
#      구별     총 계  16년이전설치
# 0     계  102380    11692
# 23  강남구    7721     1486
# 21  관악구    5842     1025
# 17  구로구    5449      607
# 22  서초구    5395      779
# 12  은평구    5027      841

# %%
seoul_cctv.loc[6, '16년이전설치']=1

# %%
#기존 데이터를 활용한 새로운 컬럼만들기
seoul_cctv['16년이전설치']
seoul_cctv.구별 #숫자가 포함되지 않은 칼럼이름은 이런식으로 불러올 수 있음

seoul_cctv['최근 증가율']=((seoul_cctv['총 계']-seoul_cctv['16년이전설치'])/seoul_cctv['16년이전설치'])*100 #100분율로 바꾸기 다 선택하고 () 넣어주는 테크닉

# %%
seoul_cctv.head(15)
# Out:
#       구별     총 계  16년이전설치         최근 증가율
# 0      계  102380    11692     775.641464
# 1    종로구    2290      230     895.652174
# 2    중 구    3021      376     703.457447
# 3    용산구    3300      106    3013.207547
# 4    성동구    4514      542     732.841328
# 5    광진구    4156      403     931.265509
# 6   동대문구    3446        1  344500.000000
# 7    중랑구    4512      479     841.962422
# 8    성북구    4543      320    1319.687500
# 9    강북구    3584       44    8045.454545
# 10   도봉구    2378        3   79166.666667
# 11   노원구    3111      592     425.506757
# 12   은평구    5027      841     497.740785
# 13  서대문구    3799      505     652.277228
# 14   마포구    3361      244    1277.459016

# %%
seoul_cctv.tail()
# Out:
#      구분   총 계  2016년 이전 설치된 CCTV   16년이전설치
# 21  관악구  5842                1025      NaN
# 22  서초구  5395                 779      NaN
# 23  강남구  7721                1486      NaN
# 24  송파구  4126                 370      NaN
# 25  강동구  3549                 725      NaN

# %%
seoul_cctv.sort_values(by='최근 증가율', ascending=False).head()
# Out:
#       구별   총 계  16년이전설치         최근 증가율
# 6   동대문구  3446        1  344500.000000
# 10   도봉구  2378        3   79166.666667
# 9    강북구  3584       44    8045.454545
# 18   금천구  3170       92    3345.652174
# 3    용산구  3300      106    3013.207547

# %%
seoul_popul.head()
# Out:
#       동별  동별(2) 2024 2/4 2024 2/4.1 2024 2/4.2 2024 2/4.3 2024 2/4.4  \
# 0  동별(1)  동별(2)  세대 (세대)      계 (명)      계 (명)      계 (명)    한국인 (명)
# 1  동별(1)  동별(2)       소계         소계         남자         여자         소계
# 2     합계     소계  4486014    9619861    4634458    4985403    9366283
# 3     합계    종로구    72394     150204      71684      78520     139189
# 4     합계     중구    65273     131800      63383      68417     121475
#
#   2024 2/4.5 2024 2/4.6 2024 2/4.7 2024 2/4.8 2024 2/4.9 2024 2/4.10  \
# 0    한국인 (명)    한국인 (명)  등록외국인 (명)  등록외국인 (명)  등록외국인 (명)   세대당인구 (명)
# 1         남자         여자         소계         남자         여자          소계
# 2    4524862    4841421     253578     109596     143982        2.09
# 3      67005      72184      11015       4679       6336        1.92
# 4      58582      62893      10325       4801       5524        1.86
#
#     2024 2/4.11
# 0  65세이상고령자 (명)
# 1            소계
# 2       1785286
# 3         29338
# 4         26516

# %%
seoul_popul.drop([0])
# Out:
#        동별  동별(2) 2024 2/4 2024 2/4.1 2024 2/4.2 2024 2/4.3 2024 2/4.4  \
# 1   동별(1)  동별(2)       소계         소계         남자         여자         소계
# 2      합계     소계  4486014    9619861    4634458    4985403    9366283
# 3      합계    종로구    72394     150204      71684      78520     139189
# 4      합계     중구    65273     131800      63383      68417     121475
# 5      합계    용산구   104187     219451     105752     113699     206061
# 6      합계    성동구   133233     283853     136993     146860     276597
# 7      합계    광진구   170469     350005     166736     183269     334159
# 8      합계   동대문구   173903     360066     174065     186001     341345
# 9      합계    중랑구   188664     386782     188839     197943     381126
# 10     합계    성북구   197371     436666     207814     228852     424194
# 11     합계    강북구   143075     290252     139521     150731     285054
# 12     합계    도봉구   138849     308060     148775     159285     305400
# ...

# %%
seoul_popul.tail()
# Out:
#     동별 동별(2) 2024 2/4 2024 2/4.1 2024 2/4.2 2024 2/4.3 2024 2/4.4 2024 2/4.5  \
# 23  합계   관악구   286338     497632     248813     248819     481145     242251
# 24  합계   서초구   170464     411959     196029     215930     407404     193838
# 25  합계   강남구   245046     562136     268628     293508     556570     266101
# 26  합계   송파구   287380     658768     315963     342805     652752     313205
# 27  합계   강동구   205956     466924     227732     239192     462646     225871
#
#    2024 2/4.6 2024 2/4.7 2024 2/4.8 2024 2/4.9 2024 2/4.10 2024 2/4.11
# 23     238894      16487       6562       9925        1.68       87267
# 24     213566       4555       2191       2364        2.39       67191
# 25     290469       5566       2527       3039        2.27       89719
# 26     339547       6016       2758       3258        2.27      111724
# 27     236775       4278       1861       2417        2.25       85571

# %%
seoul_popul.drop(['동별','2024 2/4','2024 2/4.2','2024 2/4.3','2024 2/4.5', '2024 2/4.6','2024 2/4.8',
       '2024 2/4.9', '2024 2/4.10'],axis=1, inplace=True)

# %%
seoul_popul.head()
# Out:
#    동별(2) 2024 2/4.1 2024 2/4.4 2024 2/4.7   2024 2/4.11
# 0  동별(2)      계 (명)    한국인 (명)  등록외국인 (명)  65세이상고령자 (명)
# 1  동별(2)         소계         소계         소계            소계
# 2     소계    9619861    9366283     253578       1785286
# 3    종로구     150204     139189      11015         29338
# 4     중구     131800     121475      10325         26516

# %%
seoul_popul.head()
for i in range(1,5):
  seoul_popul.rename(columns={seoul_popul.columns[i]:seoul_popul.loc[0][i]},inplace=True)
# Out:
# <ipython-input-16-aec08a45f7ff>:3: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   seoul_popul.rename(columns={seoul_popul.columns[i]:seoul_popul.loc[0][i]},inplace=True)

# %%
seoul_popul.head()
# Out:
#    동별(2)    계 (명)  한국인 (명)  등록외국인 (명)  65세이상고령자 (명)
# 0  동별(2)    계 (명)  한국인 (명)  등록외국인 (명)  65세이상고령자 (명)
# 1  동별(2)       소계       소계         소계            소계
# 2     소계  9619861  9366283     253578       1785286
# 3    종로구   150204   139189      11015         29338
# 4     중구   131800   121475      10325         26516

# %%
#seoul_popul.loc[0][0]

seoul_popul.columns[1]

seoul_popul.drop([0],inplace=True)

# %%
seoul_popul.head()
# Out:
#    동별(2)    계 (명)  한국인 (명) 등록외국인 (명) 65세이상고령자 (명)
# 1  동별(2)       소계       소계        소계           소계
# 2     소계  9619861  9366283    253578      1785286
# 3    종로구   150204   139189     11015        29338
# 4     중구   131800   121475     10325        26516
# 5    용산구   219451   206061     13390        39021

# %%
seoul_popul.rename(columns={seoul_popul.columns[0]:'구별'},inplace=True)
seoul_popul.rename(columns={seoul_popul.columns[1]:'인구'},inplace=True)
seoul_popul.rename(columns={seoul_popul.columns[2]:'한국인'},inplace=True)
seoul_popul.rename(columns={seoul_popul.columns[3]:'외국인'},inplace=True)
seoul_popul.rename(columns={seoul_popul.columns[4]:'고령자'},inplace=True)

# %%
seoul_popul.head()
# Out:
#       구별       인구      한국인     외국인      고령자
# 1  동별(2)       소계       소계      소계       소계
# 2     소계  9619861  9366283  253578  1785286
# 3    종로구   150204   139189   11015    29338
# 4     중구   131800   121475   10325    26516
# 5    용산구   219451   206061   13390    39021

# %%
seoul_popul.drop([1],inplace=True)

# %%
seoul_popul.head()
# Out:
#     구별       인구      한국인     외국인      고령자
# 2   소계  9619861  9366283  253578  1785286
# 3  종로구   150204   139189   11015    29338
# 4   중구   131800   121475   10325    26516
# 5  용산구   219451   206061   13390    39021
# 6  성동구   283853   276597    7256    50534

# %%
type(seoul_popul['인구'][2])
# Out:
# numpy.int64

# %%
for i in ['인구', '한국인', '외국인','고령자']:
  seoul_popul[i]=seoul_popul[i].astype(int)

# %%
seoul_popul['외국인 비율']=(seoul_popul['외국인'] / seoul_popul['인구'])*100
seoul_popul['고령자 비율']=(seoul_popul['고령자'] / seoul_popul['인구'])*100

# %%
seoul_popul.head()
# Out:
#     구별       인구      한국인     외국인      고령자    외국인 비율     고령자 비율
# 2   소계  9619861  9366283  253578  1785286  2.635984  18.558335
# 3  종로구   150204   139189   11015    29338  7.333360  19.532103
# 4   중구   131800   121475   10325    26516  7.833839  20.118361
# 5  용산구   219451   206061   13390    39021  6.101590  17.781190
# 6  성동구   283853   276597    7256    50534  2.556253  17.802877

# %%
seoul_popul.tail()
# Out:
#      구별      인구     한국인    외국인     고령자    외국인 비율     고령자 비율
# 23  관악구  497632  481145  16487   87267  3.313091  17.536453
# 24  서초구  411959  407404   4555   67191  1.105693  16.310118
# 25  강남구  562136  556570   5566   89719  0.990152  15.960373
# 26  송파구  658768  652752   6016  111724  0.913220  16.959537
# 27  강동구  466924  462646   4278   85571  0.916209  18.326537

# %%
seoul_popul.reset_index(drop=True, inplace=True)

# %%
seoul_popul.tail()
# Out:
#      구별      인구     한국인    외국인     고령자    외국인 비율     고령자 비율
# 21  관악구  497632  481145  16487   87267  3.313091  17.536453
# 22  서초구  411959  407404   4555   67191  1.105693  16.310118
# 23  강남구  562136  556570   5566   89719  0.990152  15.960373
# 24  송파구  658768  652752   6016  111724  0.913220  16.959537
# 25  강동구  466924  462646   4278   85571  0.916209  18.326537

# %%
seoul_popul.sort_values(by='인구', ascending=False).head(10)
# Out:
#      구별       인구      한국인     외국인      고령자    외국인 비율     고령자 비율
# 0    소계  9619861  9366283  253578  1785286  2.635984  18.558335
# 24  송파구   658768   652752    6016   111724  0.913220  16.959537
# 16  강서구   565133   559335    5798   105023  1.025953  18.583767
# 23  강남구   562136   556570    5566    89719  0.990152  15.960373
# 11  노원구   500045   495183    4862    98515  0.972312  19.701227
# 21  관악구   497632   481145   16487    87267  3.313091  17.536453
# 12  은평구   468976   464738    4238    96177  0.903671  20.507872
# 25  강동구   466924   462646    4278    85571  0.916209  18.326537
# 8   성북구   436666   424194   12472    81965  2.856188  18.770639
# 15  양천구   436595   433307    3288    78399  0.753101  17.956917

# %%
seoul_cctv.loc[2, '구별']='중구'

# %%
# 데이터 병합

seoul_cctv.head(26)
# Out:
#       구별     총 계  16년이전설치         최근 증가율
# 0      계  102380    11692     775.641464
# 1    종로구    2290      230     895.652174
# 2     중구    3021      376     703.457447
# 3    용산구    3300      106    3013.207547
# 4    성동구    4514      542     732.841328
# 5    광진구    4156      403     931.265509
# 6   동대문구    3446        1  344500.000000
# 7    중랑구    4512      479     841.962422
# 8    성북구    4543      320    1319.687500
# 9    강북구    3584       44    8045.454545
# 10   도봉구    2378        3   79166.666667
# 11   노원구    3111      592     425.506757
# 12   은평구    5027      841     497.740785
# 13  서대문구    3799      505     652.277228
# 14   마포구    3361      244    1277.459016
# 15   양천구    4447      220    1921.363636
# 16   강서구    3627      491     638.696538
# 17   구로구    5449      607     797.693575
# 18   금천구    3170       92    3345.652174
# 19  영등포구    4697      727     546.079780
# 20   동작구    3315      485     583.505155
# 21   관악구    5842     1025     469.951220
# ...

# %%
seoul_popul.head(26)
# Out:
#       구별       인구      한국인     외국인      고령자    외국인 비율     고령자 비율
# 0     소계  9619861  9366283  253578  1785286  2.635984  18.558335
# 1    종로구   150204   139189   11015    29338  7.333360  19.532103
# 2     중구   131800   121475   10325    26516  7.833839  20.118361
# 3    용산구   219451   206061   13390    39021  6.101590  17.781190
# 4    성동구   283853   276597    7256    50534  2.556253  17.802877
# 5    광진구   350005   334159   15846    58307  4.527364  16.658905
# 6   동대문구   360066   341345   18721    68503  5.199325  19.025123
# 7    중랑구   386782   381126    5656    81160  1.462322  20.983396
# 8    성북구   436666   424194   12472    81965  2.856188  18.770639
# 9    강북구   290252   285054    5198    69922  1.790858  24.090101
# 10   도봉구   308060   305400    2660    72365  0.863468  23.490554
# 11   노원구   500045   495183    4862    98515  0.972312  19.701227
# 12   은평구   468976   464738    4238    96177  0.903671  20.507872
# ...

# %%
#데이터를 합치는 조건
#조건1. 인덱스 개수가 동일한 상황 조건
len(seoul_cctv), len(seoul_popul)
#조건2. 기준 컬럼 필요 '구별'
# Out:
# (26, 26)

# %%
data_result=pd.merge(seoul_cctv,seoul_popul,on='구별') #중 구 / 중구 이렇게 조금이라도 다르니까 구별에서 merge 되지 않고 값 버려버림

# %%
data_result.head()
# Out:
#     구별   총 계  16년이전설치       최근 증가율      인구     한국인    외국인    고령자    외국인 비율  \
# 0  종로구  2290      230   895.652174  150204  139189  11015  29338  7.333360
# 1   중구  3021      376   703.457447  131800  121475  10325  26516  7.833839
# 2  용산구  3300      106  3013.207547  219451  206061  13390  39021  6.101590
# 3  성동구  4514      542   732.841328  283853  276597   7256  50534  2.556253
# 4  광진구  4156      403   931.265509  350005  334159  15846  58307  4.527364
#
#       고령자 비율
# 0  19.532103
# 1  20.118361
# 2  17.781190
# 3  17.802877
# 4  16.658905

# %%
#칼럼삭제

unused_columns =['16년이전설치' , '최근 증가율']
data_result.drop(unused_columns, axis=1)
# Out:
#       구별   총 계      인구     한국인    외국인     고령자    외국인 비율     고령자 비율
# 0    종로구  2290  150204  139189  11015   29338  7.333360  19.532103
# 1    용산구  3300  219451  206061  13390   39021  6.101590  17.781190
# 2    성동구  4514  283853  276597   7256   50534  2.556253  17.802877
# 3    광진구  4156  350005  334159  15846   58307  4.527364  16.658905
# 4   동대문구  3446  360066  341345  18721   68503  5.199325  19.025123
# 5    중랑구  4512  386782  381126   5656   81160  1.462322  20.983396
# 6    성북구  4543  436666  424194  12472   81965  2.856188  18.770639
# 7    강북구  3584  290252  285054   5198   69922  1.790858  24.090101
# 8    도봉구  2378  308060  305400   2660   72365  0.863468  23.490554
# 9    노원구  3111  500045  495183   4862   98515  0.972312  19.701227
# 10   은평구  5027  468976  464738   4238   96177  0.903671  20.507872
# 11  서대문구  3799  320010  305369  14641   59275  4.575170  18.522859
# 12   마포구  3361  373980  363029  10951   59004  2.928231  15.777314
# ...

# %%
#구별 컬럼을 인덱스로 사용

data_result.set_index(keys='구별', inplace=True)

# %%
data_result.index
# Out:
# Index(['종로구', '중구', '용산구', '성동구', '광진구', '동대문구', '중랑구', '성북구', '강북구', '도봉구',
#        '노원구', '은평구', '서대문구', '마포구', '양천구', '강서구', '구로구', '금천구', '영등포구', '동작구',
#        '관악구', '서초구', '강남구', '송파구', '강동구'],
#       dtype='object', name='구별')

# %%
data_result['CCTV 비율']=(data_result['총 계']/data_result['인구'])*100

# %%
data_result.head()
# Out:
#        총 계  16년이전설치         최근 증가율      인구     한국인    외국인    고령자    외국인 비율  \
# 구별
# 종로구   2290      230     895.652174  150204  139189  11015  29338  7.333360
# 용산구   3300      106    3013.207547  219451  206061  13390  39021  6.101590
# 성동구   4514      542     732.841328  283853  276597   7256  50534  2.556253
# 광진구   4156      403     931.265509  350005  334159  15846  58307  4.527364
# 동대문구  3446        1  344500.000000  360066  341345  18721  68503  5.199325
#
#          고령자 비율   CCTV 비율
# 구별
# 종로구   19.532103  1.524593
# 용산구   17.781190  1.503753
# 성동구   17.802877  1.590260
# 광진구   16.658905  1.187412
# 동대문구  19.025123  0.957047

# %%
# !pip install koreanize_matplotlib
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 7.9/7.9 MB 49.2 MB/s eta 0:00:00
# ...

# %%
import matplotlib.pyplot as plt
import koreanize_matplotlib

# %%
data_result.head()
# Out:
#        총 계  16년이전설치         최근 증가율      인구     한국인    외국인    고령자    외국인 비율  \
# 구별
# 종로구   2290      230     895.652174  150204  139189  11015  29338  7.333360
# 용산구   3300      106    3013.207547  219451  206061  13390  39021  6.101590
# 성동구   4514      542     732.841328  283853  276597   7256  50534  2.556253
# 광진구   4156      403     931.265509  350005  334159  15846  58307  4.527364
# 동대문구  3446        1  344500.000000  360066  341345  18721  68503  5.199325
#
#          고령자 비율   CCTV 비율
# 구별
# 종로구   19.532103  1.524593
# 용산구   17.781190  1.503753
# 성동구   17.802877  1.590260
# 광진구   16.658905  1.187412
# 동대문구  19.025123  0.957047

# %%
data_result['인구'].plot(kind='barh', figsize=(8,8)); #matplotlib 한글데이터 X / bar horizon / ;인덱스 정보 없어짐

# %%
data_result['총 계'].plot(kind='barh',figsize=(8,8));

# %%
data_result.to_csv('/content/cctv_popul_in_seoul.csv')

# %%
data_result.head()
# Out:
#        총 계  16년이전설치         최근 증가율      인구     한국인    외국인    고령자    외국인 비율  \
# 구별
# 종로구   2290      230     895.652174  150204  139189  11015  29338  7.333360
# 용산구   3300      106    3013.207547  219451  206061  13390  39021  6.101590
# 성동구   4514      542     732.841328  283853  276597   7256  50534  2.556253
# 광진구   4156      403     931.265509  350005  334159  15846  58307  4.527364
# 동대문구  3446        1  344500.000000  360066  341345  18721  68503  5.199325
#
#          고령자 비율   CCTV 비율
# 구별
# 종로구   19.532103  1.524593
# 용산구   17.781190  1.503753
# 성동구   17.802877  1.590260
# 광진구   16.658905  1.187412
# 동대문구  19.025123  0.957047
